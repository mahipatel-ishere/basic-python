# %%
f=open("file1.txt","r+")
x=f.read()
y=f.write("apples")
print(x)
print(y)
print(f.read())
print("is we can write",f.writable())
print("is we can read",f.readable())
f.close()
# Out:
# hello how are you?
# its a blooming summer
# includes mangoes crunchapplesapplesapplesapplesapplesapples
# 6
#
# is we can write True
# is we can read True

# %%
f=open("file1.txt","w+")
y=f.write("hii")
x=f.read()
print(y)
print(x)
#overwritting
# Out:
# 3

# %%
f=open("file1.txt")
print(f.read())
f.close()
# Out:
# hello how are you?
# its a blooming summer
# includes mangoes crunch

# %%
f=open("file2.txt","w+")
x=f.write("not you \nits me")
f.close()
f=open("file2.txt")
print(f.read())
f.close()
# Out:
# not you
# its me

# %% [markdown]
# hello how are you?
# its a blooming summer
# includes mangoes crunch

# %%
f=open("file3.txt","w")
x=f.write("Hello whts up!!!")
f.close()

# %%
f=open("file4.txt","w+")
f.writelines(["1","mahi","3"])
l=["1\n","2\n","3"]
f.writelines(l)
f.close()

# %%
f=open("file4.txt","r+")
f.readlines()
f.close()

# %%
f=open("file1.txt","r+")
x=f.readlines()
print(x)
# Out:
# ['hello how are you?\n', 'its a blooming summer\n', 'includes mangoes crunchapplesapplesapplesapplesapplesapplesapples']

# %%
print("reverse",x[::-1])
print("reverse",x[1::])
# Out:
# reverse ['includes mangoes crunchapplesapplesapplesapplesapplesapplesapples', 'its a blooming summer\n', 'hello how are you?\n']
# reverse ['its a blooming summer\n', 'includes mangoes crunchapplesapplesapplesapplesapplesapplesapples']
