# %%
x=eval(input(" enter a tuple : "))
y=()
print(type(y))
print(x)
print(type(x))
for i in x:
    print(i)
# Out:
#  enter a tuple :  (1,12)
# <class 'tuple'>
# (1, 12)
# <class 'tuple'>
# 1
# 12

# %%
t=("apple",13,5,"nice")
print(t[0])
print(t[-2])
print(t[-1::-1])
print(t[0: ])
print(t[0: ])
print(t[-3:-1])
del t
print(t)
# Out:
# apple
# 5
# ('nice', 5, 13, 'apple')
# ('apple', 13, 5, 'nice')
# ('apple', 13, 5, 'nice')
# (13, 5)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 9
#       7 print(t[-3:-1])
#       8 del t
# ----> 9 print(t)
#
# NameError: name 't' is not defined

# %%
t=("apple",13,5,"nice")
x=t*3
print(t)
print(x)
# Out:
# ('apple', 13, 5, 'nice')
# ('apple', 13, 5, 'nice', 'apple', 13, 5, 'nice', 'apple', 13, 5, 'nice')

# %%
t=("apple",13,5,"nice",5,67,5)
x=t.count("apple")
print(x)
# Out:
# 1

# %%
a=(1,2,3)
b=(1,2,5)
print(a!=b)
# Out:
# True

# %%
t=(4,2,3,1)
print("ascending:",sorted(t))
print("decending:",sorted(t,reverse=True))
print("min :",min(t))
print("max:",max(t))
# Out:
# ascending: [1, 2, 3, 4]
# decending: [4, 3, 2, 1]
# min : 1
# max: 4

# %%
t=(4,2,3,1)
print(t[1:1])
print(t[0:2]+t[3:])
# Out:
# ()
# (4, 2, 1)

# %%
t=eval(input("enter a tuple:"))
x=int(input("enter a index to remove:"))

print(t[:]+t[x:])
# Out:
# enter a tuple: (12,13,56)
# enter a index to remove: 2
# (12, 56)

# %%
t="hello world"
i=3
print(t[:i]+t[i+1:])
# Out:
# helo world

# %%
s="Hello whrld"
sub="h"
for i in range(len(s)):
    if s[i:i+len(sub)].lower()==sub.lower():
        print(i)
# Out:
# 0
# 7

# %%
s="Hello whrld"
for i in range(len(s)):
    if i%2==0:
        print(s[i])
# Out:
# H
# l
# o
# w
# r
# d
